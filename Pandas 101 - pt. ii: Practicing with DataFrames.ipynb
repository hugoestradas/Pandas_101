# %%
import pandas as pd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = [
      ['001', 6548, 456, 'first'], 
      ['002', 17, 258, 'second'], 
      ['003', 745, 651, 'third'], 
      ['004', 2, 104, 'fourth'], 
]
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df = pd.DataFrame(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
print(df)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">     0     1    2       3
# 0  001  6548  456   first
# 1  002    17  258  second
# 2  003   745  651   third
# 3  004     2  104  fourth
# </div>

# %%
df.columns=["col_one", "col_two", "col_three", "col_four"]
df.columns = df.columns.str.replace(" ", "_")
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col_one</th>
#       <th>col_two</th>
#       <th>col_three</th>
#       <th>col_four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>001</td>
#       <td>6548</td>
#       <td>456</td>
#       <td>first</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>002</td>
#       <td>17</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>003</td>
#       <td>745</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>004</td>
#       <td>2</td>
#       <td>104</td>
# ...

# %%
df.columns = df.columns.str.replace("_", " ")
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col one</th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>001</td>
#       <td>6548</td>
#       <td>456</td>
#       <td>first</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>002</td>
#       <td>17</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>003</td>
#       <td>745</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>004</td>
#       <td>2</td>
#       <td>104</td>
# ...

# %%
df.index = df['col one']
df.pop('col one')
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#     <tr>
#       <th>col one</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>001</th>
#       <td>6548</td>
#       <td>456</td>
#       <td>first</td>
#     </tr>
#     <tr>
#       <th>002</th>
#       <td>17</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>003</th>
#       <td>745</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>004</th>
#       <td>2</td>
#       <td>104</td>
# ...

# %%
df['col two'] = df['col three'].apply(lambda x : x+df['col two'])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#     <tr>
#       <th>col one</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>001</th>
#       <td>7004</td>
#       <td>456</td>
#       <td>first</td>
#     </tr>
#     <tr>
#       <th>002</th>
#       <td>6806</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>003</th>
#       <td>7199</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>004</th>
#       <td>6652</td>
#       <td>104</td>
# ...

# %%
df = df.drop(df.index[[0]])
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#     <tr>
#       <th>col one</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>002</th>
#       <td>6806</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>003</th>
#       <td>7199</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>004</th>
#       <td>6652</td>
#       <td>104</td>
#       <td>fourth</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df2 = df.copy()
df2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#     <tr>
#       <th>col one</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>002</th>
#       <td>6806</td>
#       <td>258</td>
#       <td>second</td>
#     </tr>
#     <tr>
#       <th>003</th>
#       <td>7199</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#     <tr>
#       <th>004</th>
#       <td>6652</td>
#       <td>104</td>
#       <td>fourth</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = df.loc[df['col two'] > 7000]
df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>col two</th>
#       <th>col three</th>
#       <th>col four</th>
#     </tr>
#     <tr>
#       <th>col one</th>
#       <th></th>
#       <th></th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>003</th>
#       <td>7199</td>
#       <td>651</td>
#       <td>third</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df = pd.read_csv("/dbfs/FileStore/tables/WordsByCharacter.csv")
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Film</th>
#       <th>Chapter</th>
#       <th>Character</th>
#       <th>Race</th>
#       <th>Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
#       <td>Bilbo</td>
#       <td>Hobbit</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
#       <td>Elrond</td>
#       <td>Elf</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
# ...

# %%
df.info()
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Film</th>
#       <th>Chapter</th>
#       <th>Character</th>
#       <th>Race</th>
#       <th>Words</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
#       <td>Bilbo</td>
#       <td>Hobbit</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
#       <td>Elrond</td>
#       <td>Elf</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>The Fellowship Of The Ring</td>
#       <td>01: Prologue</td>
# ...

# %%
df.index.names
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[25]: FrozenList([None])</div>

# %%
multiindex = df.set_index(['Film', 'Chapter', 'Race', 'Character'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
multiindex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Words</th>
#     </tr>
#     <tr>
#       <th>Film</th>
#       <th>Chapter</th>
#       <th>Race</th>
#       <th>Character</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">The Fellowship Of The Ring</th>
#       <th rowspan="4" valign="top">01: Prologue</th>
#       <th>Hobbit</th>
#       <th>Bilbo</th>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th rowspan="2" valign="top">Elf</th>
#       <th>Elrond</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Galadriel</th>
# ...

# %%
multiindex.index.names
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[29]: FrozenList([&#39;Film&#39;, &#39;Chapter&#39;, &#39;Race&#39;, &#39;Character&#39;])</div>

# %%
multiindex.index.values
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[32]: array([(&#39;The Fellowship Of The Ring&#39;, &#39;01: Prologue&#39;, &#39;Hobbit&#39;, &#39;Bilbo&#39;),
#        (&#39;The Fellowship Of The Ring&#39;, &#39;01: Prologue&#39;, &#39;Elf&#39;, &#39;Elrond&#39;),
#        (&#39;The Fellowship Of The Ring&#39;, &#39;01: Prologue&#39;, &#39;Elf&#39;, &#39;Galadriel&#39;),
#        (&#39;The Fellowship Of The Ring&#39;, &#39;01: Prologue&#39;, &#39;Gollum&#39;, &#39;Gollum&#39;),
#        (&#39;The Fellowship Of The Ring&#39;, &#39;02: Concerning Hobbits&#39;, &#39;Hobbit&#39;, &#39;Bilbo&#39;),
# ...

# %%
multiindex = df.set_index(['Film', 'Chapter', 'Race', 'Character']).sort_index()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
multiindex
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th></th>
#       <th></th>
#       <th></th>
#       <th>Words</th>
#     </tr>
#     <tr>
#       <th>Film</th>
#       <th>Chapter</th>
#       <th>Race</th>
#       <th>Character</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th rowspan="30" valign="top">The Fellowship Of The Ring</th>
#       <th rowspan="4" valign="top">01: Prologue</th>
#       <th rowspan="2" valign="top">Elf</th>
#       <th>Elrond</th>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>Galadriel</th>
#       <td>460</td>
#     </tr>
#     <tr>
#       <th>Gollum</th>
#       <th>Gollum</th>
# ...

# %%
df = pd.read_csv('/dbfs/FileStore/tables/drinks.csv')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer_servings</th>
#       <th>spirit_servings</th>
#       <th>wine_servings</th>
#       <th>total_litres_of_pure_alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Albania</td>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Algeria</td>
# ...

# %%
df.dtypes
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[39]: country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object</div>

# %%
df.select_dtypes(include='number').head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>beer_servings</th>
#       <th>spirit_servings</th>
#       <th>wine_servings</th>
#       <th>total_litres_of_pure_alcohol</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>25</td>
#       <td>0</td>
#       <td>14</td>
#       <td>0.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>245</td>
#       <td>138</td>
# ...

# %%
df.select_dtypes(exclude='number').head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Albania</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Algeria</td>
#       <td>Africa</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Andorra</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Angola</td>
#       <td>Africa</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
df.select_dtypes(include=['number', 'object', 'category']).head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>country</th>
#       <th>beer_servings</th>
#       <th>spirit_servings</th>
#       <th>wine_servings</th>
#       <th>total_litres_of_pure_alcohol</th>
#       <th>continent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Afghanistan</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>0.0</td>
#       <td>Asia</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Albania</td>
#       <td>89</td>
#       <td>132</td>
#       <td>54</td>
#       <td>4.9</td>
#       <td>Europe</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Algeria</td>
# ...

# %%
df.info(memory_usage='deep')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 6 columns):
# country                         193 non-null object
# beer_servings                   193 non-null int64
# spirit_servings                 193 non-null int64
# wine_servings                   193 non-null int64
# total_litres_of_pure_alcohol    193 non-null float64
# continent                       193 non-null object
# dtypes: float64(1), int64(3), object(2)
# memory usage: 30.4 KB
# </div>

# %%
cols = ['beer_servings', 'continent']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
small_drinks = pd.read_csv('/dbfs/FileStore/tables/drinks.csv', usecols=cols)
small_drinks.info(memory_usage='deep')
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">&lt;class &#39;pandas.core.frame.DataFrame&#39;&gt;
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 2 columns):
# beer_servings    193 non-null int64
# continent        193 non-null object
# dtypes: int64(1), object(1)
# memory usage: 13.6 KB
# </div>
